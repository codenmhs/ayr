# %% [markdown]
# # Assignment 5: 'The Matrix' by the Wachowskis

# %% [markdown]
# ## Part 1: Triangular Numbers

# %%
sum = 0 
for i in range(1, 11): 
    sum += 1
    
print(sum)
# Out:
# 10

# %% [markdown]
# Here's what's happening above:
# 1. Create a container called "sum" and store the number zero in it
# 1. Create a loop that runs 10 times, once for each of these values of the container "i" : 1, 2, 3, ... , 10
# 1. Each time through the loop, add 1 to the number stored in "sum"
# 1. Print the resulting sum.

# %% [markdown]
# Here is your task.  Given a number of rows in a pyramid built like this, tell me the total number of elements.
#
# ![triang_nums.png](attachment:triang_nums.png)
#
# So, from this example, if I said "3 rows" you'd answer "6 elements total".
#
# You can solve this problem by looking for a clever pattern, or by modifying the code above.
#
# I'll test your solution by giving you a very large number, so make sure you're using code to do the math.

# %%
sum = 0 
for i in range(10): 
    sum += 1
    
print(sum)
# Out:
# 10

# %% [markdown]
# ## Part 2: Tetrahedral Numbers

# %% [markdown]
# Once you've solved that, let's move on to square pyramids in 3D, built the following way:
#
# ![square_pyr_nums_3.png](attachment:square_pyr_nums_3.png)

# %% [markdown]
# ![square_pyr_nums.gif](attachment:square_pyr_nums.gif)
#
# Once again, given a number of rows, tell me the number of elements.  Use code to do it.

# %%
sum = 0 
for i in range(10): 
    sum += 1
    
print(sum)
# Out:
# 10

# %% [markdown]
# The Great Pyramid of Giza has about 205 levels [1].  Assume it is built with the shape above.  How many blocks are in the pyramid?
#
# ![image info](./media/giza_above.jpg)
#
# [1] McKenzie, D. The Course Thicknesses of the Great Pyramid. Nexus Netw J 18, 347–372 (2016). https://doi.org/10.1007/s00004-016-0296-6
